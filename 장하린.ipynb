# %% [markdown]
# 1. 서울 연료별 자동차

# %%
import pandas as pd
import pymysql


conn=pymysql.connect(host='database-1.cf8mgu8iylh3.ap-northeast-2.rds.amazonaws.com',port=3306,user='root',password='42314231',db='project')
sql="select * from 서울시_연료별_자동차"

SeoulVehiclesFuel = pd.read_sql_query(sql,conn)
conn.close()
SeoulVehiclesFuel.head()
# Out:
# /tmp/ipykernel_4660/3173151173.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   SeoulVehiclesFuel = pd.read_sql_query(sql,conn)
#   시군구별 연료별   용도별    승용  승합   화물 특수
# 0  종로구  전기  비사업용   686   1   76  0
# 1  종로구  전기   사업용    30  12  102  0
# 2   중구  전기  비사업용  1008   4  610  1
# 3   중구  전기   사업용   465   0   64  0
# 4  용산구  전기  비사업용  1022   3   90  0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

# 가능한 font list 확인
import matplotlib.font_manager as fm
f = [f.name for f in fm.fontManager.ttflist]
print(f)
# Out:
# ['STIXSizeTwoSym', 'cmb10', 'STIXGeneral', 'STIXGeneral', 'STIXSizeFourSym', 'cmtt10', 'STIXNonUnicode', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Serif Display', 'STIXSizeOneSym', 'DejaVu Sans Mono', 'STIXSizeTwoSym', 'cmex10', 'DejaVu Serif', 'DejaVu Sans', 'cmmi10', 'cmss10', 'cmsy10', 'STIXSizeThreeSym', 'DejaVu Serif', 'DejaVu Sans Mono', 'STIXNonUnicode', 'cmr10', 'DejaVu Sans Display', 'DejaVu Serif', 'STIXSizeOneSym', 'STIXSizeThreeSym', 'DejaVu Sans', 'STIXGeneral', 'DejaVu Sans Mono', 'STIXSizeFourSym', 'STIXNonUnicode', 'DejaVu Sans', 'STIXGeneral', 'STIXSizeFiveSym', 'DejaVu Serif', 'DejaVu Sans Mono', 'FreeSans', 'Keraleeyam', 'Mallanna', 'Potti Sreeramulu', 'padmaa', 'KacstLetter', 'Rachana', 'AnjaliOldLipi', 'Liberation Serif', 'URW Bookman', 'Liberation Serif', 'Liberation Serif', 'Nimbus Sans', 'Tlwg Typist', 'Ubuntu Mono', 'Norasi', 'Noto Sans CJK JP', 'Liberation Sans Narrow', 'Noto Serif CJK JP', 'Ani', 'Lohit Telugu', 'Vemana2000', 'NATS', 'Ubuntu', 'Ubuntu', 'Gayathri', 'Manjari', 'Jamrul', 'Kinnari', 'Mitra ', 'Yrsa', 'DejaVu Sans', 'LakkiReddy', 'Kalimati', 'padmaa-Bold.1.1', 'Mandali', 'C059', 'Nimbus Mono PS', 'Nimbus Roman', 'Noto Sans CJK JP', 'KacstBook', 'Navilu', 'Tlwg Typist', 'Ponnala', 'Lohit Bengali', 'Phetsarath OT', 'Tlwg Typist', 'Ubuntu', 'Gidugu', 'URW Gothic', 'KacstTitle', 'Ubuntu Mono', 'Dhurjati', 'Noto Sans CJK JP', 'ori1Uni', 'DejaVu Serif', 'Liberation Serif', 'Padauk', 'Norasi', 'Waree', 'Liberation Sans', 'Tlwg Typo', 'Kinnari', 'Norasi', 'Liberation Mono', 'FreeSerif', 'Liberation Serif', 'Abyssinica SIL', 'URW Gothic', 'Padauk Book', 'Yrsa', 'Karumbi', 'Kinnari', 'Noto Sans CJK JP', 'DejaVu Sans Mono', 'Manjari', 'Padauk', 'URW Bookman', 'Ramaraja', 'Lohit Tamil', 'Mukti', 'Norasi', 'Ubuntu', 'KacstPoster', 'Lohit Tamil Classical', 'Liberation Sans', 'KacstOne', 'Suranna', 'Manjari', 'FreeMono', 'Liberation Mono', 'Sree Krushnadevaraya', 'Kinnari', 'FreeMono', 'Lohit Gurmukhi', 'Yrsa', 'FreeMono', 'Dyuthi', 'Liberation Sans', 'Yrsa', 'Liberation Mono', 'Ubuntu', 'Mukti', 'Nimbus Sans Narrow', 'Noto Serif CJK JP', 'Umpush', 'Meera', 'Kinnari', 'Lohit Malayalam', 'C059', 'Tlwg Typo', 'Nimbus Roman', 'Kalapi', 'P052', 'Gurajada', 'P052', 'P052', 'Purisa', 'Sahadeva', 'Nimbus Sans', 'Noto Mono', 'Ramabhadra', 'FreeSans', 'URW Gothic', 'P052', 'Tlwg Typo', 'Liberation Mono', 'Tlwg Typist', 'Loma', 'DejaVu Sans Mono', 'Samyak Devanagari', 'Ubuntu', 'Rasa', 'Ubuntu Mono', 'LKLUG', 'Liberation Mono', 'KacstArt', 'Sawasdee', 'Chandas', 'aakar', 'Laksaman', 'Garuda', 'Ubuntu', 'Nimbus Mono PS', 'Liberation Sans', 'Pothana2000', 'Noto Sans CJK JP', 'Garuda', 'Z003', 'Loma', 'padmaa', 'Chilanka', 'Samyak Gujarati', 'Peddana', 'Standard Symbols PS', 'Nimbus Roman', 'Liberation Serif', 'Liberation Sans Narrow', 'Loma', 'Lohit Kannada', 'KacstPen', 'Samyak Tamil', 'Droid Sans Fallback', 'FreeSans', 'Khmer OS', 'Umpush', 'Padauk Book', 'RaviPrakash', 'Nakula', 'Purisa', 'Laksaman', 'RaghuMalayalamSans', 'OpenSymbol', 'KacstDecorative', 'Ubuntu Mono', 'Loma', 'FreeSerif', 'Tlwg Typewriter', 'Tlwg Typewriter', 'Norasi', 'DejaVu Serif', 'Gargi', 'Timmana', 'NTR', 'Nimbus Sans Narrow', 'Noto Serif CJK JP', 'Yrsa', 'Rasa', 'URW Bookman', 'Yrsa', 'C059', 'Tlwg Mono', 'Garuda', 'FreeMono', 'Waree', 'Sawasdee', 'Nimbus Sans Narrow', 'Liberation Mono', 'Ubuntu', 'Suravaram', 'Norasi', 'URW Gothic', 'Rasa', 'Kinnari', 'Noto Serif CJK JP', 'FreeSerif', 'Tlwg Typo', 'Laksaman', 'FreeSans', 'Garuda', 'KacstOffice', 'Noto Sans CJK JP', 'mry_KacstQurn', 'Lohit Gujarati', 'Umpush', 'Nimbus Sans', 'Pagul', 'Syamala Ramana', 'Liberation Sans', 'Tlwg Typewriter', 'C059', 'Liberation Sans Narrow', 'Yrsa', 'Waree', 'FreeSerif', 'Gayathri', 'Liberation Mono', 'Tibetan Machine Uni', 'Rasa', 'Noto Serif CJK JP', 'Lohit Odia', 'Umpush', 'Liberation Sans', 'Rekha', 'Uroob', 'Liberation Sans Narrow', 'KacstNaskh', 'Waree', 'Sarai', 'Lohit Assamese', 'Laksaman', 'Lohit Devanagari', 'DejaVu Sans', 'URW Bookman', 'Nimbus R ...

# %%
plt.rc('font', family='NanumGothic')

# %%
SeoulVehiclesFuel['승용'] = SeoulVehiclesFuel['승용'].astype('float')
SeoulVehiclesFuel['승합'] = SeoulVehiclesFuel['승합'].astype('float')
SeoulVehiclesFuel['화물'] = SeoulVehiclesFuel['화물'].astype('float')
SeoulVehiclesFuel['특수'] = SeoulVehiclesFuel['특수'].astype('float')

# %%
SeoulVehiclesFuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    50 non-null     object
#  1   연료별     50 non-null     object
#  2   용도별     50 non-null     object
#  3   승용      50 non-null     float64
#  4   승합      50 non-null     float64
#  5   화물      50 non-null     float64
#  6   특수      50 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
sns.set(color_codes=True)
sns.set_palette("pastel")
plt.rc('font', family='NanumGothic') # 한글 표시 위함 
plt.figure(figsize=(12, 8))
fig, ax = plt.subplots(2, 2, figsize=(15, 15))

# '시군구별'로 승용, 승합, 화물, 특수의 막대그래프 그리기
sns.barplot(x='시군구별', y='승용', hue='용도별', data=SeoulVehiclesFuel,ax=ax[0,0])
sns.barplot(x='시군구별', y='승합', hue='용도별', data=SeoulVehiclesFuel,ax=ax[0,1])
sns.barplot(x='시군구별', y='화물', hue='용도별', data=SeoulVehiclesFuel,ax=ax[1,0])
sns.barplot(x='시군구별', y='특수', hue='용도별', data=SeoulVehiclesFuel,ax=ax[1,1])

for axes_row in ax:
    for axis in axes_row:
        axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha='right')
        axis.tick_params(axis='x', labelsize=8)
        
ax[0,0].set_title('승용차 등록 현황')
ax[0,1].set_title('승합차 등록 현황')
ax[1,0].set_title('화물차 등록 현황')
ax[1,1].set_title('특수차 등록 현황')

ax[0,0].legend()
plt.show()
# Out:
# /tmp/ipykernel_4660/2712746253.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_4660/2712746253.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_4660/2712746253.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_4660/2712746253.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(axis.get_xticklabels(), rotation=45, ha='right')

# %%
sns.set(color_codes=True)
sns.set_palette("pastel")
plt.rc('font', family='NanumGothic')  # 한글 표시 위함
plt.figure(figsize=(15, 15))

fig, ax = plt.subplots(2, 2, figsize=(12, 12))

heatmap_data1 = SeoulVehiclesFuel.pivot_table(values='승용', index='시군구별', columns='용도별')
sns.heatmap(heatmap_data1, cmap='RdPu', annot=True, fmt=".1f", ax=ax[0, 0])

heatmap_data2 = SeoulVehiclesFuel.pivot_table(values='승합', index='시군구별', columns='용도별')
sns.heatmap(heatmap_data2, cmap='RdPu', annot=True, fmt=".1f", ax=ax[0, 1])

heatmap_data3 = SeoulVehiclesFuel.pivot_table(values='화물', index='시군구별', columns='용도별')
sns.heatmap(heatmap_data3, cmap='BuGn', annot=True, fmt=".1f", ax=ax[1, 0])

heatmap_data4 = SeoulVehiclesFuel.pivot_table(values='특수', index='시군구별', columns='용도별')
sns.heatmap(heatmap_data4, cmap='BuGn', annot=True, fmt=".1f", ax=ax[1, 1])

plt.tight_layout() # 그래프 사이 간격 조절 
plt.show()

# %% [markdown]
# 서울 충전소 설치현황

# %%
import pandas as pd
import pymysql


conn=pymysql.connect(host='database-1.cf8mgu8iylh3.ap-northeast-2.rds.amazonaws.com',port=3306,user='root',password='42314231',db='project')
sql="select * from 전기차_충전소_위치_연도별"

ChargingStation = pd.read_sql_query(sql,conn)
conn.close()
ChargingStation.head()
# Out:
# /tmp/ipykernel_4660/2797023671.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ChargingStation = pd.read_sql_query(sql,conn)
#    YEAR   CITY TOWNSHIP               ADDRESS    CHARGING_NAME FACILITY_LARGE  \
# 0  2017  서울특별시      강동구   서울특별시 강동구 고덕로28길 36       암사1동 공영주차장           주차시설
# 1  2017  서울특별시      강동구      서울특별시 강동구 선사로 70      천호유수지 공영주차장           주차시설
# 2  2017  서울특별시      강동구  서울특별시 강동구 진황도로29길 34     천호3동 제1공영주차장           주차시설
# 3  2017  서울특별시      강서구   서울특별시 강서구 가로공원로 189    가로공원로 지하공영주차장           주차시설
# 4  2017  서울특별시      강서구    서울특별시 강서구 강서로5길 50  곰달래문화복지센터 공영주차장           주차시설
#
#   FACILITY_SMALL EMPHYSEMA  RAPIDITY OPERATING_ORG_LARGE OPERATING_ORG_SMALL  \
# 0          공영주차장        급속  급속(50kW)                 환경부             환경부(협회)
# 1          공영주차장        급속  급속(50kW)                 환경부             환경부(협회)
# 2          공영주차장        급속  급속(50kW)                 환경부             환경부(협회)
# 3          공영주차장        급속  급속(50kW)                 환경부             환경부(협회)
# 4          공영주차장        급속  급속(50kW)                 환경부             환경부(협회)
#
#   RAPID_CHARGING_AMOUNT     CHARGER_TYPE USER_RESTRIC CHARGER_ID
# 0              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능          1
# 1              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능          1
# 2              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능          1
# 3              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능          1
# 4              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능          1

# %%
# '구' 별로 정리 - 컬럼 추가 
# 급속 충전기 합, 완속 충전기 합

# %% [markdown]
# 데이터 다듬기 ~

# %%
# 서울데이터만 뽑기, 인덱스 초기화, 재정렬
SeoulChargingStation=ChargingStation[ChargingStation['CITY']=='서울특별시']
SeoulChargingStation.reset_index(inplace=True, drop=True)
SeoulChargingStation
# Out:
#        YEAR   CITY TOWNSHIP               ADDRESS    CHARGING_NAME  \
# 0      2017  서울특별시      강동구   서울특별시 강동구 고덕로28길 36       암사1동 공영주차장
# 1      2017  서울특별시      강동구      서울특별시 강동구 선사로 70      천호유수지 공영주차장
# 2      2017  서울특별시      강동구  서울특별시 강동구 진황도로29길 34     천호3동 제1공영주차장
# 3      2017  서울특별시      강서구   서울특별시 강서구 가로공원로 189    가로공원로 지하공영주차장
# 4      2017  서울특별시      강서구    서울특별시 강서구 강서로5길 50  곰달래문화복지센터 공영주차장
# ...     ...    ...      ...                   ...              ...
# 45376  2023  서울특별시              서울특별시 영등포구 은행로 25        안원빌딩 지하2층
# 45377  2023  서울특별시              서울특별시 영등포구 은행로 25        안원빌딩 지하2층
# 45378  2012  서울특별시       중구     서울특별시 중구 세종대로 110          서울시 신청사
# 45379  2015  서울특별시      양천구   서울특별시 양천구 중앙로 341-3             명화운수
# 45380  2015  서울특별시      성동구     서울특별시 성동구 서울숲길 41             대한상운
#
#       FACILITY_LARGE FACILITY_SMALL EMPHYSEMA    RAPIDITY OPERATING_ORG_LARGE  \
# 0               주차시설          공영주차장        급속    급속(50kW)                 환경부
# 1               주차시설          공영주차장        급속    급속(50kW)                 환경부
# 2               주차시설          공영주차장        급속    급속(50kW)                 환경부
# 3               주차시설          공영주차장        급속    급속(50kW)                 환경부
# 4               주차시설          공영주차장        급속    급속(50kW)                 환경부
# ...              ...            ...       ...         ...                 ...
# 45376                            기타        완속        AC완속            타기관(보조금)
# 45377                            기타        완속        AC완속            타기관(보조금)
# 45378           공공시설           공공기관        급속  DC차데모+AC3상                 지자체
# 45379           기타시설             기타        급속        AC3상                 지자체
# 45380           기타시설             기타        급속        AC3상                 지자체
#
#       OPERATING_ORG_SMALL RAPID_CHARGING_AMOUNT     CHARGER_TYPE USER_RESTRIC  \
# 0                 환경부(협회)              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능
# 1                 환경부(협회)              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능
# 2                 환경부(협회)              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능
# 3                 환경부(협회)              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능
# 4                 환경부(협회)              급속(50kW)  DC차데모+AC3상+DC콤보         이용가능
# ...                   ...                   ...              ...          ...
# 45376               한화솔루션                                   AC완속         이용가능
# 45377               한화솔루션                                   AC완속         이용가능
# 45378               지자체기타                             DC차데모+AC3상        이용자제한
# 45379               지자체기타                                   AC3상        이용자제한
# 45380               지자체기타                                   AC3상        이용자제한
#
#       CHARGER_ID
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 45376          1
# 45377          2
# 45378          1
# 45379          1
# 45380          1
#
# [45381 rows x 15 columns]

# %%
# 칼럼명 수정 
SeoulChargingStation.rename(columns={'YEAR':'설치년도','CITY':'시도','TOWNSHIP':'군구','ADDRESS':'주소','YEAR':'설치년도','YEAR':'설치년도','CHARGING_NAME':'충전소명',
                                'FACILITY_LARGE':'시설구분(대)','FACILITY_SMALL':'시설구분(소)','EMPHYSEMA':'기종(대)','RAPIDITY':'기종(소)','OPERATING_ORG_LARGE':'운영기관(대)',
                                'OPERATING_ORG_SMALL':'운영기관(소)','RAPID_CHARGING_AMOUNT':'급속충전량','CHARGER_TYPE':'충전기타입','USER_RESTRIC':'이용자제한',
                                'CHARGER_ID':'충전기ID',},inplace=True)
SeoulChargingStation
# Out:
# /tmp/ipykernel_4660/2865429520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.rename(columns={'YEAR':'설치년도','CITY':'시도','TOWNSHIP':'군구','ADDRESS':'주소','YEAR':'설치년도','YEAR':'설치년도','CHARGING_NAME':'충전소명',
#        설치년도     시도   군구                    주소             충전소명 시설구분(대)  \
# 0      2017  서울특별시  강동구   서울특별시 강동구 고덕로28길 36       암사1동 공영주차장    주차시설
# 1      2017  서울특별시  강동구      서울특별시 강동구 선사로 70      천호유수지 공영주차장    주차시설
# 2      2017  서울특별시  강동구  서울특별시 강동구 진황도로29길 34     천호3동 제1공영주차장    주차시설
# 3      2017  서울특별시  강서구   서울특별시 강서구 가로공원로 189    가로공원로 지하공영주차장    주차시설
# 4      2017  서울특별시  강서구    서울특별시 강서구 강서로5길 50  곰달래문화복지센터 공영주차장    주차시설
# ...     ...    ...  ...                   ...              ...     ...
# 45376  2023  서울특별시          서울특별시 영등포구 은행로 25        안원빌딩 지하2층
# 45377  2023  서울특별시          서울특별시 영등포구 은행로 25        안원빌딩 지하2층
# 45378  2012  서울특별시   중구     서울특별시 중구 세종대로 110          서울시 신청사    공공시설
# 45379  2015  서울특별시  양천구   서울특별시 양천구 중앙로 341-3             명화운수    기타시설
# 45380  2015  서울특별시  성동구     서울특별시 성동구 서울숲길 41             대한상운    기타시설
#
#       시설구분(소) 기종(대)       기종(소)   운영기관(대)  운영기관(소)     급속충전량            충전기타입  \
# 0       공영주차장    급속    급속(50kW)       환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보
# 1       공영주차장    급속    급속(50kW)       환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보
# 2       공영주차장    급속    급속(50kW)       환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보
# 3       공영주차장    급속    급속(50kW)       환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보
# 4       공영주차장    급속    급속(50kW)       환경부  환경부(협회)  급속(50kW)  DC차데모+AC3상+DC콤보
# ...       ...   ...         ...       ...      ...       ...              ...
# 45376      기타    완속        AC완속  타기관(보조금)    한화솔루션                       AC완속
# 45377      기타    완속        AC완속  타기관(보조금)    한화솔루션                       AC완속
# 45378    공공기관    급속  DC차데모+AC3상       지자체    지자체기타                 DC차데모+AC3상
# 45379      기타    급속        AC3상       지자체    지자체기타                       AC3상
# 45380      기타    급속        AC3상       지자체    지자체기타                       AC3상
#
#        이용자제한 충전기ID
# 0       이용가능     1
# 1       이용가능     1
# 2       이용가능     1
# 3       이용가능     1
# 4       이용가능     1
# ...      ...   ...
# 45376   이용가능     1
# 45377   이용가능     2
# 45378  이용자제한     1
# 45379  이용자제한     1
# 45380  이용자제한     1
#
# [45381 rows x 15 columns]

# %%
# '군구' 칼럼에서 빈 값 찾기 
empty_rows = SeoulChargingStation[SeoulChargingStation['군구'].apply(lambda x: isinstance(x, (str, bytes)) and x.strip() == '')]
empty_rows
# Out:
#        설치년도     시도 군구                  주소           충전소명 시설구분(대) 시설구분(소)  \
# 12050  2023  서울특별시      서울 강서구 공항대로59길 64     한사랑2차삼성아파트  공동주택시설     아파트
# 12051  2023  서울특별시      서울 강서구 공항대로59길 64     한사랑2차삼성아파트  공동주택시설     아파트
# 12052  2023  서울특별시      서울 강서구 공항대로59길 64     한사랑2차삼성아파트  공동주택시설     아파트
# 12053  2023  서울특별시      서울 강서구 공항대로59길 64     한사랑2차삼성아파트  공동주택시설     아파트
# 35879  2023  서울특별시      서울 영등포구 신길로61길 21  영등포본동 제1공영주차장    주차시설   공영주차장
# ...     ...    ... ..                 ...            ...     ...     ...
# 45373  2023  서울특별시     서울특별시 양천구 목동동로 437  항도드림네스트 지하주차장              기타
# 45374  2023  서울특별시      서울특별시 영등포구 은행로 25      안원빌딩 지하3층              기타
# 45375  2023  서울특별시      서울특별시 영등포구 은행로 25      안원빌딩 지하3층              기타
# 45376  2023  서울특별시      서울특별시 영등포구 은행로 25      안원빌딩 지하2층              기타
# 45377  2023  서울특별시      서울특별시 영등포구 은행로 25      안원빌딩 지하2층              기타
#
#       기종(대) 기종(소)   운영기관(대)  운영기관(소) 급속충전량 충전기타입  이용자제한 충전기ID
# 12050    완속  AC완속  타기관(보조금)   지에스커넥트        AC완속  이용자제한     1
# 12051    완속  AC완속  타기관(보조금)   지에스커넥트        AC완속  이용자제한     2
# 12052    완속  AC완속  타기관(보조금)   지에스커넥트        AC완속  이용자제한     3
# 12053    완속  AC완속  타기관(보조금)   지에스커넥트        AC완속  이용자제한     4
# 35879    완속  AC완속       타기관  서울에너지공사        AC완속   이용가능     1
# ...     ...   ...       ...      ...   ...   ...    ...   ...
# 45373    완속  AC완속  타기관(보조금)    한화솔루션        AC완속   이용가능     2
# 45374    완속  AC완속  타기관(보조금)    한화솔루션        AC완속   이용가능     1
# 45375    완속  AC완속  타기관(보조금)    한화솔루션        AC완속   이용가능     2
# 45376    완속  AC완속  타기관(보조금)    한화솔루션        AC완속   이용가능     1
# 45377    완속  AC완속  타기관(보조금)    한화솔루션        AC완속   이용가능     2
#
# [81 rows x 15 columns]

# %%
# '군구' 빈 칼럼 채우기 25개 구...
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강남구', case=False, na=False), '군구'] = '강남구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강동구', case=False, na=False), '군구'] = '강동구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강북구', case=False, na=False), '군구'] = '강북구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강서구', case=False, na=False), '군구'] = '강서구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('관악구', case=False, na=False), '군구'] = '관악구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('광진구', case=False, na=False), '군구'] = '광진구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('구로구', case=False, na=False), '군구'] = '구로구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('금천구', case=False, na=False), '군구'] = '금천구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('노원구', case=False, na=False), '군구'] = '노원구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('도봉구', case=False, na=False), '군구'] = '도봉구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('동대문구', case=False, na=False), '군구'] = '동대문구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('동작구', case=False, na=False), '군구'] = '동작구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('마포구', case=False, na=False), '군구'] = '마포구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('서대문구', case=False, na=False), '군구'] = '서대문구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('서초구', case=False, na=False), '군구'] = '서초구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('성동구', case=False, na=False), '군구'] = '성동구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('성북구', case=False, na=False), '군구'] = '성북구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('송파구', case=False, na=False), '군구'] = '송파구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('양천구', case=False, na=False), '군구'] = '양천구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('영등포구', case=False, na=False), '군구'] = '영등포구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('용산구', case=False, na=False), '군구'] = '용산구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('은평구', case=False, na=False), '군구'] = '은평구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('종로구', case=False, na=False), '군구'] = '종로구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('중구', case=False, na=False), '군구'] = '중구'
SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('중랑구', case=False, na=False), '군구'] = '중랑구'
# Out:
# /tmp/ipykernel_4660/837519281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강남구', case=False, na=False), '군구'] = '강남구'
# /tmp/ipykernel_4660/837519281.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강동구', case=False, na=False), '군구'] = '강동구'
# /tmp/ipykernel_4660/837519281.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강북구', case=False, na=False), '군구'] = '강북구'
# /tmp/ipykernel_4660/837519281.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('강서구', case=False, na=False), '군구'] = '강서구'
# /tmp/ipykernel_4660/837519281.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('관악구', case=False, na=False), '군구'] = '관악구'
# /tmp/ipykernel_4660/837519281.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('광진구', case=False, na=False), '군구'] = '광진구'
# /tmp/ipykernel_4660/837519281.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('구로구', case=False, na=False), '군구'] = '구로구'
# /tmp/ipykernel_4660/837519281.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('금천구', case=False, na=False), '군구'] = '금천구'
# /tmp/ipykernel_4660/837519281.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('노원구', case=False, na=False), '군구'] = '노원구'
# /tmp/ipykernel_4660/837519281.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('도봉구', case=False, na=False), '군구'] = '도봉구'
# /tmp/ipykernel_4660/837519281.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('동대문구', case=False, na=False), '군구'] = '동대문구'
# /tmp/ipykernel_4660/837519281.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('동작구', case=False, na=False), '군구'] = '동작구'
# /tmp/ipykernel_4660/837519281.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('마포구', case=False, na=False), '군구'] = '마포구'
# /tmp/ipykernel_4660/837519281.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('서대문구', case=False, na=False), '군구'] = '서대문구'
# /tmp/ipykernel_4660/837519281.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('서초구', case=False, na=False), '군구'] = '서초구'
# /tmp/ipykernel_4660/837519281.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('성동구', case=False, na=False), '군구'] = '성동구'
# /tmp/ipykernel_4660/837519281.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('성북구', case=False, na=False), '군구'] = '성북구'
# /tmp/ipykernel_4660/837519281.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('송파구', case=False, na=False), '군구'] = '송파구'
# /tmp/ipykernel_4660/837519281.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('양천구', case=False, na=False), '군구'] = '양천구'
# /tmp/ipykernel_4660/837519281.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('영등포구', case=False, na=False), '군구'] = '영등포구'
# /tmp/ipykernel_4660/837519281.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('용산구', case=False, na=False), '군구'] = '용산구'
# /tmp/ipykernel_4660/837519281.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('은평구', case=False, na=False), '군구'] = '은평구'
# /tmp/ipykernel_4660/837519281.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('종로구', case=False, na=False), '군구'] = '종로구'
# /tmp/ipykernel_4660/837519281.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('중구', case=False, na=False), '군구'] = '중구'
# /tmp/ipykernel_4660/837519281.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['주소'].str.contains('중랑구', case=False, na=False), '군구'] = '중랑구'

# %%
# '군구' 칼럼에서 빈 값 찾기 -> 다 채워짐
empty_rows = SeoulChargingStation[SeoulChargingStation['군구'].apply(lambda x: isinstance(x, (str, bytes)) and x.strip() == '')]
empty_rows
# Out:
# Empty DataFrame
# Columns: [설치년도, 시도, 군구, 주소, 충전소명, 시설구분(대), 시설구분(소), 기종(대), 기종(소), 운영기관(대), 운영기관(소), 급속충전량, 충전기타입, 이용자제한, 충전기ID]
# Index: []

# %%
# 시설구분(대)도 비어있는지 확인 
empty_rows = SeoulChargingStation[SeoulChargingStation['시설구분(대)'].apply(lambda x: isinstance(x, (str, bytes)) and x.strip() == '')]
empty_rows
# Out:
#        설치년도     시도    군구                  주소           충전소명 시설구분(대) 시설구분(소)  \
# 45296  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45297  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45298  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45299  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45300  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45301  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45302  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45303  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45304  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45305  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45306  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45307  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45308  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45309  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45310  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45311  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45312  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45313  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45314  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45315  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45316  2023  서울특별시   광진구  서울특별시 광진구 광나루로 458   이편한세상광진그랜드파크              기타
# 45344  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45345  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45346  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45347  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45348  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45349  2023  서울특별시   강남구  서울특별시 강남구 영동대로 731           신영빌딩              기타
# 45350  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45351  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45352  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45353  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45354  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45355  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45356  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45357  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45358  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45359  2023  서울특별시   동작구   서울특별시 동작구 노량진로 74        유한양행 본사              기타
# 45372  2023  서울특별시   양천구  서울특별시 양천구 목동동로 437  항도드림네스트 지하주차장              기타
# 45373  2023  서울특별시   양천구  서울특별시 양천구 목동동로 437  항도드림네스트 지하주차장              기타
# 45374  2023  서울특별시  영등포구   서울특별시 영등포구 은행로 25      안원빌딩 지하3층              기타
# 45375  2023  서울특별시  영등포구   서울특별시 영등포구 은행로 25      안원빌딩 지하3층              기타
# 45376  2023  서울특별시  영등포구   서울특별시 영등포구 은행로 25      안원빌딩 지하2층              기타
# 45377  2023  서울특별시  영등포구   서울특별시 영등포구 은행로 25      안원빌딩 지하2층              기타
#
#       기종(대) 기종(소)   운영기관(대) 운영기관(소) 급속충전량 충전기타입 이용자제한 충전기ID
# 45296    급속  DC콤보       타기관   한화솔루션        DC콤보  이용가능     1
# 45297    급속  DC콤보       타기관   한화솔루션        DC콤보  이용가능     2
# 45298    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     3
# 45299    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     4
# 45300    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     5
# 45301    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     6
# 45302    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     7
# 45303    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     8
# 45304    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     9
# 45305    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    10
# 45306    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    11
# 45307    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    12
# 45308    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    13
# 45309    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    14
# 45310    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    15
# 45311    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    16
# 45312    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    17
# 45313    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    18
# 45314    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    19
# 45315    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    20
# 45316    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    21
# 45344    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     1
# 45345    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     2
# 45346    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     3
# 45347    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     4
# 45348    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     5
# 45349    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     6
# 45350    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     1
# 45351    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     3
# 45352    완속  AC완속       타기관   한화솔루션        AC완속  이용가능     9
# 45353    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    10
# 45354    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    11
# 45355    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    12
# 45356    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    16
# 45357    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    17
# 45358    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    18
# 45359    완속  AC완속       타기관   한화솔루션        AC완속  이용가능    19
# 45372    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     1
# 45373    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     2
# 45374    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     1
# 45375    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     2
# 45376    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     1
# 45377    완속  AC완속  타기관(보조금)   한화솔루션        AC완속  이용가능     2

# %%
SeoulChargingStation.loc[SeoulChargingStation['시설구분(소)'].str.contains('기타', case=False, na=False), '시설구분(대)'] = '기타시설'
# Out:
# /tmp/ipykernel_4660/3653332516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SeoulChargingStation.loc[SeoulChargingStation['시설구분(소)'].str.contains('기타', case=False, na=False), '시설구분(대)'] = '기타시설'

# %%
# 채워졌는지 확인
empty_rows = SeoulChargingStation[SeoulChargingStation['시설구분(대)'].apply(lambda x: isinstance(x, (str, bytes)) and x.strip() == '')]
empty_rows
# Out:
# Empty DataFrame
# Columns: [설치년도, 시도, 군구, 주소, 충전소명, 시설구분(대), 시설구분(소), 기종(대), 기종(소), 운영기관(대), 운영기관(소), 급속충전량, 충전기타입, 이용자제한, 충전기ID]
# Index: []

# %%
SeoulChargingStation.tail(10)
# Out:
#        설치년도     시도    군구                     주소           충전소명 시설구분(대)  \
# 45371  2023  서울특별시   양천구  서울특별시 양천구 남부순환로85길 16          대주파크빌  공동주택시설
# 45372  2023  서울특별시   양천구     서울특별시 양천구 목동동로 437  항도드림네스트 지하주차장    기타시설
# 45373  2023  서울특별시   양천구     서울특별시 양천구 목동동로 437  항도드림네스트 지하주차장    기타시설
# 45374  2023  서울특별시  영등포구      서울특별시 영등포구 은행로 25      안원빌딩 지하3층    기타시설
# 45375  2023  서울특별시  영등포구      서울특별시 영등포구 은행로 25      안원빌딩 지하3층    기타시설
# 45376  2023  서울특별시  영등포구      서울특별시 영등포구 은행로 25      안원빌딩 지하2층    기타시설
# 45377  2023  서울특별시  영등포구      서울특별시 영등포구 은행로 25      안원빌딩 지하2층    기타시설
# 45378  2012  서울특별시    중구      서울특별시 중구 세종대로 110        서울시 신청사    공공시설
# 45379  2015  서울특별시   양천구    서울특별시 양천구 중앙로 341-3           명화운수    기타시설
# 45380  2015  서울특별시   성동구      서울특별시 성동구 서울숲길 41           대한상운    기타시설
#
#       시설구분(소) 기종(대)       기종(소)   운영기관(대) 운영기관(소) 급속충전량       충전기타입  이용자제한  \
# 45371     아파트    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45372      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45373      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45374      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45375      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45376      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45377      기타    완속        AC완속  타기관(보조금)   한화솔루션              AC완속   이용가능
# 45378    공공기관    급속  DC차데모+AC3상       지자체   지자체기타        DC차데모+AC3상  이용자제한
# 45379      기타    급속        AC3상       지자체   지자체기타              AC3상  이용자제한
# 45380      기타    급속        AC3상       지자체   지자체기타              AC3상  이용자제한
#
#       충전기ID
# 45371     4
# 45372     1
# 45373     2
# 45374     1
# 45375     2
# 45376     1
# 45377     2
# 45378     1
# 45379     1
# 45380     1

# %%
SeoulChargingStation.to_csv('../data/SeoulChargingStation.csv',sep=',',encoding='utf-8')

# %% [markdown]
# ~ 데이터 다듬기

# %%
SeoulChargingStation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45381 entries, 0 to 45380
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   설치년도     45381 non-null  object
#  1   시도       45381 non-null  object
#  2   군구       45381 non-null  object
#  3   주소       45381 non-null  object
#  4   충전소명     45381 non-null  object
#  5   시설구분(대)  45381 non-null  object
#  6   시설구분(소)  45381 non-null  object
#  7   기종(대)    45381 non-null  object
#  8   기종(소)    45381 non-null  object
#  9   운영기관(대)  45381 non-null  object
#  10  운영기관(소)  45381 non-null  object
#  11  급속충전량    45381 non-null  object
#  12  충전기타입    45381 non-null  object
#  13  이용자제한    45381 non-null  object
#  14  충전기ID    45381 non-null  object
# dtypes: object(15)
# memory usage: 5.2+ MB

# %% [markdown]
# 충전소 설치 수

# %%
import pandas as pd


df = pd.DataFrame(SeoulChargingStation)

# '설치년도'별 '군구'별 충전소 설치 수 
count = df.groupby(['설치년도', '군구']).size().reset_index(name='충전소갯수')
count
# Out:
#      설치년도    군구  충전소갯수
# 0    2012   노원구      3
# 1    2012   서초구      2
# 2    2012  영등포구      1
# 3    2012    중구      1
# 4    2012   중랑구      2
# ..    ...   ...    ...
# 203  2023   용산구    527
# 204  2023   은평구    551
# 205  2023   종로구    175
# 206  2023    중구    309
# 207  2023   중랑구    323
#
# [208 rows x 3 columns]

# %%
count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   설치년도    208 non-null    object
#  1   군구      208 non-null    object
#  2   충전소갯수   208 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB

# %%
df = pd.DataFrame(count)

# '군구'에 따른 충전소 설치 수 
count_by_gungu = df.groupby('군구')['충전소갯수'].sum().reset_index(name='충전소갯수')

count_by_gungu
# Out:
#       군구  충전소갯수
# 0    강남구   3613
# 1    강동구   1709
# 2    강북구    835
# 3    강서구   2604
# 4    관악구    963
# 5    광진구    851
# 6    구로구   2177
# 7    금천구   1414
# 8    노원구   2012
# 9    도봉구   1049
# 10  동대문구   1287
# 11   동작구   1530
# 12   마포구   2227
# 13  서대문구   1238
# 14   서초구   3055
# 15   성동구   2462
# 16   성북구   2291
# 17   송파구   3183
# 18   양천구   1363
# 19  영등포구   2050
# 20   용산구   1465
# 21   은평구   1966
# 22   종로구    934
# 23    중구   1331
# 24   중랑구   1772

# %%
SeoulVehiclesFuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    50 non-null     object
#  1   연료별     50 non-null     object
#  2   용도별     50 non-null     object
#  3   승용      50 non-null     float64
#  4   승합      50 non-null     float64
#  5   화물      50 non-null     float64
#  6   특수      50 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
# 1번에서 사용했던 데이터 불러와서 구 마다 전기차 등록대수 계산 

import pandas as pd
df=[]
df = pd.DataFrame(SeoulVehiclesFuel)

# '승용', '승합', '화물', '특수'의 합을 계산하고 새로운 열 '총합' 추가
df['총합'] = df[['승용', '승합', '화물', '특수']].sum(axis=1)
df.head()
# Out:
#   시군구별 연료별   용도별      승용    승합     화물   특수      총합
# 0  종로구  전기  비사업용   686.0   1.0   76.0  0.0   763.0
# 1  종로구  전기   사업용    30.0  12.0  102.0  0.0   144.0
# 2   중구  전기  비사업용  1008.0   4.0  610.0  1.0  1623.0
# 3   중구  전기   사업용   465.0   0.0   64.0  0.0   529.0
# 4  용산구  전기  비사업용  1022.0   3.0   90.0  0.0  1115.0

# %%
count_by_car=[]
count_by_car = df.groupby('시군구별')['총합'].sum().reset_index(name='전기차수')

count_by_car.rename(columns={'시군구별':'군구'}, inplace=True)
count_by_car
# Out:
#       군구     전기차수
# 0    강남구  14026.0
# 1    강동구   2271.0
# 2    강북구    890.0
# 3    강서구   2867.0
# 4    관악구   1355.0
# 5    광진구   1069.0
# 6    구로구   5161.0
# 7    금천구   1033.0
# 8    노원구   1561.0
# 9    도봉구   1093.0
# 10  동대문구   1112.0
# 11   동작구   1203.0
# 12   마포구   1776.0
# 13  서대문구   1221.0
# 14   서초구   4757.0
# 15   성동구   2239.0
# 16   성북구   1482.0
# 17   송파구   3273.0
# 18   양천구   1763.0
# 19  영등포구   2182.0
# 20   용산구   1201.0
# 21   은평구   1533.0
# 22   종로구    907.0
# 23    중구   2152.0
# 24   중랑구   1457.0

# %%
SeoulData = pd.merge(count_by_gungu, count_by_car)
SeoulData
# Out:
#       군구  충전소갯수     전기차수
# 0    강남구   3613  14026.0
# 1    강동구   1709   2271.0
# 2    강북구    835    890.0
# 3    강서구   2604   2867.0
# 4    관악구    963   1355.0
# 5    광진구    851   1069.0
# 6    구로구   2177   5161.0
# 7    금천구   1414   1033.0
# 8    노원구   2012   1561.0
# 9    도봉구   1049   1093.0
# 10  동대문구   1287   1112.0
# 11   동작구   1530   1203.0
# 12   마포구   2227   1776.0
# 13  서대문구   1238   1221.0
# 14   서초구   3055   4757.0
# 15   성동구   2462   2239.0
# 16   성북구   2291   1482.0
# 17   송파구   3183   3273.0
# 18   양천구   1363   1763.0
# 19  영등포구   2050   2182.0
# 20   용산구   1465   1201.0
# 21   은평구   1966   1533.0
# 22   종로구    934    907.0
# 23    중구   1331   2152.0
# 24   중랑구   1772   1457.0

# %%
SeoulData['충전소갯수'] = SeoulData['충전소갯수'].astype('float')
SeoulData.head()
# Out:
#     군구   충전소갯수     전기차수
# 0  강남구  3613.0  14026.0
# 1  강동구  1709.0   2271.0
# 2  강북구   835.0    890.0
# 3  강서구  2604.0   2867.0
# 4  관악구   963.0   1355.0

# %%
# 전기차 1대당 충전소 갯수 반올림 계산
SeoulData['비율'] = (SeoulData['전기차수'] / SeoulData['충전소갯수']).round(2)
SeoulData
# Out:
#       군구   충전소갯수     전기차수    비율
# 0    강남구  3613.0  14026.0  3.88
# 1    강동구  1709.0   2271.0  1.33
# 2    강북구   835.0    890.0  1.07
# 3    강서구  2604.0   2867.0  1.10
# 4    관악구   963.0   1355.0  1.41
# 5    광진구   851.0   1069.0  1.26
# 6    구로구  2177.0   5161.0  2.37
# 7    금천구  1414.0   1033.0  0.73
# 8    노원구  2012.0   1561.0  0.78
# 9    도봉구  1049.0   1093.0  1.04
# 10  동대문구  1287.0   1112.0  0.86
# 11   동작구  1530.0   1203.0  0.79
# 12   마포구  2227.0   1776.0  0.80
# 13  서대문구  1238.0   1221.0  0.99
# 14   서초구  3055.0   4757.0  1.56
# 15   성동구  2462.0   2239.0  0.91
# 16   성북구  2291.0   1482.0  0.65
# 17   송파구  3183.0   3273.0  1.03
# 18   양천구  1363.0   1763.0  1.29
# 19  영등포구  2050.0   2182.0  1.06
# 20   용산구  1465.0   1201.0  0.82
# 21   은평구  1966.0   1533.0  0.78
# 22   종로구   934.0    907.0  0.97
# 23    중구  1331.0   2152.0  1.62
# 24   중랑구  1772.0   1457.0  0.82

# %%
seoul_center = pd.read_csv("../data/서울시_자치구_중심점_2017.csv",encoding = 'euc-kr')
seoul_center = seoul_center[['시군구명','X','Y']]
seoul_center
# Out:
#     시군구명           X          Y
# 0    종로구  126.977321  37.594917
# 1     중구  126.995968  37.560144
# 2    용산구  126.979907  37.531385
# 3    성동구  127.041059  37.551030
# 4    광진구  127.085744  37.546706
# 5   동대문구  127.054848  37.581957
# 6    중랑구  127.092880  37.597803
# 7    성북구  127.017579  37.605702
# 8    강북구  127.011189  37.643474
# 9    도봉구  127.032369  37.669102
# 10   노원구  127.075035  37.652511
# 11   은평구  126.927023  37.619211
# 12  서대문구  126.939063  37.577785
# 13   마포구  126.908270  37.559313
# 14   양천구  126.855478  37.524789
# 15   강서구  126.822807  37.561235
# 16   구로구  126.856301  37.494405
# 17   금천구  126.900820  37.460568
# 18  영등포구  126.910169  37.522308
# 19   동작구  126.951641  37.498877
# 20   관악구  126.945337  37.467376
# 21   서초구  127.031220  37.473295
# 22   강남구  127.062985  37.496644
# 23   송파구  127.115295  37.505619
# 24   강동구  127.147012  37.550450

# %%
seoul_center = seoul_center.sort_values(by=["시군구명"], ascending=[True]) 
seoul_center_s = seoul_center.rename(columns={"시군구명":"군구"})
seoul_center_s.reset_index(drop=True)
# Out:
#       군구           X          Y
# 0    강남구  127.062985  37.496644
# 1    강동구  127.147012  37.550450
# 2    강북구  127.011189  37.643474
# 3    강서구  126.822807  37.561235
# 4    관악구  126.945337  37.467376
# 5    광진구  127.085744  37.546706
# 6    구로구  126.856301  37.494405
# 7    금천구  126.900820  37.460568
# 8    노원구  127.075035  37.652511
# 9    도봉구  127.032369  37.669102
# 10  동대문구  127.054848  37.581957
# 11   동작구  126.951641  37.498877
# 12   마포구  126.908270  37.559313
# 13  서대문구  126.939063  37.577785
# 14   서초구  127.031220  37.473295
# 15   성동구  127.041059  37.551030
# 16   성북구  127.017579  37.605702
# 17   송파구  127.115295  37.505619
# 18   양천구  126.855478  37.524789
# 19  영등포구  126.910169  37.522308
# 20   용산구  126.979907  37.531385
# 21   은평구  126.927023  37.619211
# 22   종로구  126.977321  37.594917
# 23    중구  126.995968  37.560144
# 24   중랑구  127.092880  37.597803

# %%
SeoulDataStationMean = SeoulData['충전소갯수'].mean()
SeoulDataCarMean = SeoulData['전기차수'].mean()

print("Average 충전소 갯수:", SeoulDataStationMean)
print("Average 전기차 수:", SeoulDataCarMean)
# Out:
# Average 충전소 갯수: 1815.24
# Average 전기차 수: 2383.36

# %%
SeoulData['충전소갯수_비교'] = SeoulData['충전소갯수'].apply(lambda x: '많음' if x > SeoulDataStationMean else '적음')
SeoulData['전기차수_비교'] = SeoulData['전기차수'].apply(lambda x: '많음' if x > SeoulDataCarMean else '적음')
SeoulData
# Out:
#       군구   충전소갯수     전기차수    비율 충전소갯수_비교 전기차수_비교
# 0    강남구  3613.0  14026.0  3.88       많음      많음
# 1    강동구  1709.0   2271.0  1.33       적음      적음
# 2    강북구   835.0    890.0  1.07       적음      적음
# 3    강서구  2604.0   2867.0  1.10       많음      많음
# 4    관악구   963.0   1355.0  1.41       적음      적음
# 5    광진구   851.0   1069.0  1.26       적음      적음
# 6    구로구  2177.0   5161.0  2.37       많음      많음
# 7    금천구  1414.0   1033.0  0.73       적음      적음
# 8    노원구  2012.0   1561.0  0.78       많음      적음
# 9    도봉구  1049.0   1093.0  1.04       적음      적음
# 10  동대문구  1287.0   1112.0  0.86       적음      적음
# 11   동작구  1530.0   1203.0  0.79       적음      적음
# 12   마포구  2227.0   1776.0  0.80       많음      적음
# 13  서대문구  1238.0   1221.0  0.99       적음      적음
# 14   서초구  3055.0   4757.0  1.56       많음      많음
# 15   성동구  2462.0   2239.0  0.91       많음      적음
# 16   성북구  2291.0   1482.0  0.65       많음      적음
# 17   송파구  3183.0   3273.0  1.03       많음      많음
# 18   양천구  1363.0   1763.0  1.29       적음      적음
# 19  영등포구  2050.0   2182.0  1.06       많음      적음
# 20   용산구  1465.0   1201.0  0.82       적음      적음
# 21   은평구  1966.0   1533.0  0.78       많음      적음
# 22   종로구   934.0    907.0  0.97       적음      적음
# 23    중구  1331.0   2152.0  1.62       적음      적음
# 24   중랑구  1772.0   1457.0  0.82       적음      적음

# %%
SeoulData = pd.merge(SeoulData, seoul_center_s)
SeoulData
# Out:
#       군구   충전소갯수     전기차수    비율 충전소갯수_비교 전기차수_비교           X          Y
# 0    강남구  3613.0  14026.0  3.88       많음      많음  127.062985  37.496644
# 1    강동구  1709.0   2271.0  1.33       적음      적음  127.147012  37.550450
# 2    강북구   835.0    890.0  1.07       적음      적음  127.011189  37.643474
# 3    강서구  2604.0   2867.0  1.10       많음      많음  126.822807  37.561235
# 4    관악구   963.0   1355.0  1.41       적음      적음  126.945337  37.467376
# 5    광진구   851.0   1069.0  1.26       적음      적음  127.085744  37.546706
# 6    구로구  2177.0   5161.0  2.37       많음      많음  126.856301  37.494405
# 7    금천구  1414.0   1033.0  0.73       적음      적음  126.900820  37.460568
# 8    노원구  2012.0   1561.0  0.78       많음      적음  127.075035  37.652511
# 9    도봉구  1049.0   1093.0  1.04       적음      적음  127.032369  37.669102
# 10  동대문구  1287.0   1112.0  0.86       적음      적음  127.054848  37.581957
# 11   동작구  1530.0   1203.0  0.79       적음      적음  126.951641  37.498877
# 12   마포구  2227.0   1776.0  0.80       많음      적음  126.908270  37.559313
# 13  서대문구  1238.0   1221.0  0.99       적음      적음  126.939063  37.577785
# 14   서초구  3055.0   4757.0  1.56       많음      많음  127.031220  37.473295
# 15   성동구  2462.0   2239.0  0.91       많음      적음  127.041059  37.551030
# 16   성북구  2291.0   1482.0  0.65       많음      적음  127.017579  37.605702
# 17   송파구  3183.0   3273.0  1.03       많음      많음  127.115295  37.505619
# 18   양천구  1363.0   1763.0  1.29       적음      적음  126.855478  37.524789
# 19  영등포구  2050.0   2182.0  1.06       많음      적음  126.910169  37.522308
# 20   용산구  1465.0   1201.0  0.82       적음      적음  126.979907  37.531385
# 21   은평구  1966.0   1533.0  0.78       많음      적음  126.927023  37.619211
# 22   종로구   934.0    907.0  0.97       적음      적음  126.977321  37.594917
# 23    중구  1331.0   2152.0  1.62       적음      적음  126.995968  37.560144
# 24   중랑구  1772.0   1457.0  0.82       적음      적음  127.092880  37.597803

# %%
import matplotlib.pyplot as plt

# 시각화를 위한 데이터 프레임 생성
visualization_data = SeoulData[['군구', '충전소갯수_비교', '전기차수_비교']]

# 군구별로 '충전소갯수_비교' 파이 차트
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
visualization_data['충전소갯수_비교'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('충전소갯수_비교')

# 군구별로 '전기차수_비교' 파이 차트
plt.subplot(1, 2, 2)
visualization_data['전기차수_비교'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('전기차수_비교')

plt.tight_layout()
plt.show()

# %%
merge_res = {}

# Use the .loc method to apply conditions row-wise
# Also, use parentheses for conditions and square brackets for dictionary key-value pairs
merge_res["둘다많음"] = SeoulData.loc[(SeoulData['충전소갯수_비교'] == '많음') & (SeoulData['전기차수_비교'] == '많음'), '군구'].tolist()
merge_res["둘다적음"] = SeoulData.loc[(SeoulData['충전소갯수_비교'] == '적음') & (SeoulData['전기차수_비교'] == '적음'), '군구'].tolist()
merge_res["차 많고 충전소 적음"] = SeoulData.loc[(SeoulData['충전소갯수_비교'] == '적음') & (SeoulData['전기차수_비교'] == '많음'), '군구'].tolist()
merge_res["충전소 많고 차 적음"] = SeoulData.loc[(SeoulData['충전소갯수_비교'] == '많음') & (SeoulData['전기차수_비교'] == '적음'), '군구'].tolist()

merge_res
# Out:
# {'둘다많음': ['강남구', '강서구', '구로구', '서초구', '송파구'],
#  '둘다적음': ['강동구',
#   '강북구',
#   '관악구',
#   '광진구',
#   '금천구',
#   '도봉구',
#   '동대문구',
#   '동작구',
#   '서대문구',
#   '양천구',
#   '용산구',
#   '종로구',
#   '중구',
#   '중랑구'],
#  '차 많고 충전소 적음': [],
#  '충전소 많고 차 적음': ['노원구', '마포구', '성동구', '성북구', '영등포구', '은평구']}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화를 위한 데이터 프레임 생성
visualization_data = pd.DataFrame({
    'Category': ['둘다많음', '둘다적음', '충전소 많고 차 적음'],
    'Count': [len(merge_res['둘다많음']), len(merge_res['둘다적음']), len(merge_res['충전소 많고 차 적음'])]
})

# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Count', data=visualization_data, palette='Set2')
plt.title('군구별 카테고리 수')
plt.show()

# %%
import matplotlib.pyplot as plt

# 시각화를 위한 데이터 프레임 생성
visualization_data = pd.DataFrame({
    'Category': ['둘다많음', '둘다적음', '충전소 많고 차 적음'],
    'Count': [len(merge_res['둘다많음']), len(merge_res['둘다적음']), len(merge_res['충전소 많고 차 적음'])]
})

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(visualization_data['Count'], labels=visualization_data['Category'], autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set2'))
plt.title('군구별 카테고리 비율')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.DataFrame(SeoulData)

# '전기차수'에 따른 '충전소갯수'의 상관관계 계산
correlation = np.corrcoef(df['전기차수'], df['충전소갯수'])[0, 1]

print("상관관계:", correlation)

plt.scatter(df['전기차수'], df['충전소갯수'])
plt.title('전기차수에 따른 충전소갯수의 상관관계')
plt.xlabel('전기차수')
plt.ylabel('충전소갯수')
plt.show()
# Out:
# 상관관계: 0.7101151885339506

# %%
# 지도 시각화 
import json
import folium
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
import folium
from folium import plugins 
# Create a base map
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles="OpenStreetMap")
geo_path = "../data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))
# Add Choropleth layer
folium.Choropleth(
    geo_data=geo_path,
    data=SeoulData,
    columns=['군구', '비율'],
    key_on="feature.properties.name",
    fill_color="Blues",
    fill_opacity=0.7,
    line_opacity=0.5,
    legend_name="비율",
).add_to(map)

# Add markers for each '군구'
for _, row in SeoulData.iterrows():
    popup_html = f"<strong>군구:</strong> {row['군구']}<br>"
    popup_html += f"<strong>충전소 갯수:</strong> {row['충전소갯수']}<br>"
    popup_html += f"<strong>전기차 수:</strong> {row['전기차수']}"
    
    folium.Marker(location=[row['Y'], row['X']], popup=folium.Popup(html=popup_html, max_width=200)).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_256c25da2900c21dd0a40d0d85e5fe39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_256c25da2900c21dd0a40d0d85e5fe39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_256c25da2900c21dd0a40d0d85e5fe39 = L.map(
#                 &quot;map_256c25da2900c21dd0a40d0d85e5fe39&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4177ba4622645aa18be60cf197ee2e4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4177ba4622645aa18be60cf197ee2e4f.addTo(map_256c25da2900c21dd0a40d0d85e5fe39);
#
#
#             var choropleth_a14bdb49e3f77b9d4681ae6391e07f69 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_35dd8b9a285d2efd57999366f543e754_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_35dd8b9a285d2efd57999366f543e754_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_35dd8b9a285d2efd57999366f543e754 = L.geoJson(null, {
#                 onEachFeature: geo_json_35dd8b9a285d2efd57999366f543e754_onEachFeature,
#
#                 style: geo_json_35dd8b9a285d2efd57999366f543e754_styler,
#         });
#
#         function geo_json_35dd8b9a285d2efd57999366f543e754_add (data) {
#             geo_json_35dd8b9a285d2efd57999366f543e754
#                 .addData(data);
#         }
#             geo_json_35dd8b9a285d2efd57999366f543e754_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;: &quot;Songpa-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.05867359288398, 37.52629974922568], [127.0690698130372, 37.522279423505026], [127.0719146000724, 37.50224013587669], [127.11117085201238, 37.485708381512445], [127.12440571080893, 37.46240445587048], [127.09842759318751, 37.45862253857461], [127.08640440578156, 37.472697935184655], [127.0559170481904, 37.4659228914077], [127.03621915098798, 37.48175802427603], [127.01397119667513, 37.52503988289669], [127.0230

# %%
import folium
from folium.plugins import MarkerCluster

# Create a base map
map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles="OpenStreetMap")

# Create MarkerCluster layer
marker_cluster = MarkerCluster().add_to(map)

# Add markers for each '군구' to the MarkerCluster layer
for _, row in SeoulData.iterrows():
    popup_html = f"<strong>군구:</strong> {row['군구']}<br>"
    popup_html += f"<strong>충전소 갯수:</strong> {row['충전소갯수']}<br>"
    popup_html += f"<strong>전기차 수:</strong> {row['전기차수']}"

    folium.Marker(
        location=[row['Y'], row['X']],
        popup=folium.Popup(html=popup_html, max_width=200),
    ).add_to(marker_cluster)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e725188dd580827782bf37a4d7b015a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e725188dd580827782bf37a4d7b015a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e725188dd580827782bf37a4d7b015a5 = L.map(
#                 &quot;map_e725188dd580827782bf37a4d7b015a5&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45398e4564b008dc4901f78ca08626db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45398e4564b008dc4901f78ca08626db.addTo(map_e725188dd580827782bf37a4d7b015a5);
#
#
#             var marker_cluster_63e3b4cd25f6975904a20ca865b688ab = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_fa10494f2c8f5beca4824a977b4f7901 = L.marker(
#                 [37.49664389, 127.0629852],
#                 {}
#             ).addTo(marker_cluster_63e3b4cd25f6975904a20ca865b688ab);
#
#
#         var popup_499b76f7bcc6a5a8a7d6dcdca1a3353d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_0bad5c5995e80f92967aa62c3f4262c2 = $(`&lt;div id=&quot;html_0bad5c5995e80f92967aa62c3f4262c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;군구:&lt;/strong&gt; 강남구&lt;br&gt;&lt;strong&gt;충전소 갯수:&lt;/strong&gt; 3613.0&lt;br&gt;&lt;strong&gt;전기차 수:&lt;/strong&gt; 14026.0&lt;/div&gt;`)[0];
#                 popup_499b76f7bcc6a5a8a7d6dcdca1a3353d.setContent(html_0bad5c5995e80f92967aa62c3f4262c2);
#
#
#
#         marker_fa10494f2c8f5beca4824a977b4f7901.bindPopup(popup_499b76f7bcc6a5a8a7d6dcdca1a3353d)
#         ;
#
#
#
#
#             var marker_edc28b41508abe020f677a62f21e6ca5 = L.marker(
#                 [37.55045024, 127.1470118],
#                 {}
#             ).addTo(marker_cluster_63e3b4cd25f6975904a20ca865b688ab);
#
#
#         var popup_551965d627e9287cfcdd0216117706c4 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_42316996e5fd811152eb5666cf88fd61 = $(`&lt;div id=&quot;html_42316996e5fd811152eb5666cf88fd61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;군구:&lt;/strong&gt; 강동구&lt;br&gt;&lt;strong&gt;충전소 갯수:&lt;/strong&gt; 1709.0&lt;br&gt;&lt;strong&gt;전기차 수:&lt;/strong&gt; 2271.0&lt;/div&gt;`)[0];
#                 popup_551965d627e9287cfcdd0216117706c4.setContent(html_42316996e5fd811152eb5666cf88fd61);
#
#
#
#         marker_edc28b41508abe020f677a62f21e6ca5.bindPopup(popup_551965d627e9287cfcdd0216117706c4)
#         ;
#
#
#
#
#             var marker_9221dc85101e6f54ef6fe08cf5db6e7e = L.marker(
#                 [37.64347391, 127.011189],
#                 {}
#             ).addTo(marker_cluster_63e3b4cd25f6975904a20ca865b688ab);
#
#
#         var popup_9cf443c804b688d66eb8527e25e02767 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f515166e864ba8edfddb2ace63552ba2 = $(`&lt;div id=&quot;html_f515166e864ba8edfddb2ace63552ba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;군구:&lt;/strong&gt; 강북구&lt;br&gt;&lt;strong&gt;충전소 갯수:&lt;/strong&gt; 835.0&lt;br&gt;&lt;strong&gt;전기차 수:&lt;/strong&gt; 890.0&lt;/div&gt;`)[0];
#                 popup_9cf443c804b688d66eb8527e25e02767.setContent(html_f515166e864ba8edfddb2ace63552ba2);
#
#
#
#         marker_9221dc85101e6f54ef6fe08cf5db6e7e.bindPopup(popup_9cf443c804b688d66eb8527e25e02767)
#         ;
#
#
#
#
#             var marker_af1372c47740e2d0c2ce7fc30ad9a703 = L.marker(
#                 [37.56123543, 126.822807],
#                 {}
#             ).addTo(marker_cluster_63e3b4cd25f6975904a20ca865b688ab);
#
#
#         var popup_851dcffb0f9b5ed5dd2bfd33359d81d2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7b3b94925e5fabdecebbc2c9ab7ae481 = $(`&lt;div id=&quot;html_7b3b94925e5fabdecebbc2c9ab7ae481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;군구:&lt;/strong&gt; 강서구&lt;br&gt;&lt;strong&gt;충전소 갯수:&lt;/strong&gt; 2604.0&lt;br&gt;&lt;strong&gt;전기차 수:&lt;/strong&gt; 2867.0&lt;/div&gt;`)[0];
#                 popup_851dcffb0f9b5ed5dd2bfd33359d81d2.setContent(html_7b3b94925e5fabdecebbc2c9ab7ae481);
#
#
#
#         marker_af

# %%
import pandas as pd
import pymysql


conn=pymysql.connect(host='database-1.cf8mgu8iylh3.ap-northeast-2.rds.amazonaws.com',port=3306,user='root',password='42314231',db='project')
sql="select * from 전기차_충전소_설치현황_위경도포함"

StationXY = pd.read_sql_query(sql,conn)
conn.close()
StationXY.head()
# Out:
# /tmp/ipykernel_4660/640207390.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   StationXY = pd.read_sql_query(sql,conn)
#       시구   군구        설치장소                        주소 급속충전기(대) 완속충전기(대)  \
# 0  서울특별시  강남구   LH강남힐스테이트    서울특별시 강남구 자곡동 자곡로3길 21        1        4
# 1  서울특별시  강남구      LH서울지사     서울특별시 강남구 선릉로 121길 12        1        0
# 2  서울특별시  강남구       가람아파트     서울특별시 강남구 일원동 일원로 127        1        0
# 3  서울특별시  강남구  강남구청 공영주차장        서울특별시 강남구 삼성동 16-1        1        0
# 4  서울특별시  강남구     강남데시앙파크  서울특별시 강남구 세곡동 헌릉로590길 63        1        1
#
#                                                 지원차종          위도           경도
# 0  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...           0            0
# 1  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...           0            0
# 2  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...  37.4831474  127.0853694
# 3  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...  37.5147838  127.0543618
# 4  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...  37.4623303  127.1012352

# %%
StationXY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시구        608 non-null    object
#  1   군구        608 non-null    object
#  2   설치장소      608 non-null    object
#  3   주소        608 non-null    object
#  4   급속충전기(대)  608 non-null    object
#  5   완속충전기(대)  608 non-null    object
#  6   지원차종      608 non-null    object
#  7   위도        608 non-null    object
#  8   경도        608 non-null    object
# dtypes: object(9)
# memory usage: 42.9+ KB

# %%
StationXY['급속충전기(대)'] = StationXY['급속충전기(대)'].astype('float')
StationXY['완속충전기(대)'] = StationXY['완속충전기(대)'].astype('float')
StationXY['위도'] = StationXY['위도'].astype('float')
StationXY['경도'] = StationXY['경도'].astype('float')

# %%
import folium

# Create a base map
map = folium.Map(location=[37.5502, 126.982], zoom_start=12, tiles="OpenStreetMap")

# Add markers for each location in the dataset
for _, row in StationXY.iterrows():
    popup_html = f"<strong>설치장소:</strong> {row['설치장소']}<br>"
    popup_html += f"<strong>주소:</strong> {row['주소']}<br>"
    popup_html += f"<strong>급속충전기:</strong> {row['급속충전기(대)']} 대<br>"
    popup_html += f"<strong>완속충전기:</strong> {row['완속충전기(대)']} 대<br>"
    popup_html += f"<strong>지원차종:</strong> {row['지원차종']}"

    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=folium.Popup(html=popup_html, max_width=300),
    ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_646bae944e3d31171b1b2704478c7e8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_646bae944e3d31171b1b2704478c7e8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_646bae944e3d31171b1b2704478c7e8e = L.map(
#                 &quot;map_646bae944e3d31171b1b2704478c7e8e&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88f0952c25951ef73f5f7803833fdf5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_88f0952c25951ef73f5f7803833fdf5d.addTo(map_646bae944e3d31171b1b2704478c7e8e);
#
#
#             var marker_6674d1d79cc7f4aa6855551db9fa1134 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_646bae944e3d31171b1b2704478c7e8e);
#
#
#         var popup_84296bf381ffe70fb309a5c7aaa46374 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_46ea8e5f252578a900c33fdea8789ad3 = $(`&lt;div id=&quot;html_46ea8e5f252578a900c33fdea8789ad3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;설치장소:&lt;/strong&gt; LH강남힐스테이트&lt;br&gt;&lt;strong&gt;주소:&lt;/strong&gt; 서울특별시 강남구 자곡동 자곡로3길 21&lt;br&gt;&lt;strong&gt;급속충전기:&lt;/strong&gt; 1.0 대&lt;br&gt;&lt;strong&gt;완속충전기:&lt;/strong&gt; 4.0 대&lt;br&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_84296bf381ffe70fb309a5c7aaa46374.setContent(html_46ea8e5f252578a900c33fdea8789ad3);
#
#
#
#         marker_6674d1d79cc7f4aa6855551db9fa1134.bindPopup(popup_84296bf381ffe70fb309a5c7aaa46374)
#         ;
#
#
#
#
#             var marker_b7d6e2e6cd79d3ced8c63f64b0f843b3 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_646bae944e3d31171b1b2704478c7e8e);
#
#
#         var popup_a162268df8e7cd39503bdeadd0e733ae = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_7f8c2913104e5879510e95aa34958946 = $(`&lt;div id=&quot;html_7f8c2913104e5879510e95aa34958946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;설치장소:&lt;/strong&gt; LH서울지사&lt;br&gt;&lt;strong&gt;주소:&lt;/strong&gt; 서울특별시 강남구 선릉로 121길 12&lt;br&gt;&lt;strong&gt;급속충전기:&lt;/strong&gt; 1.0 대&lt;br&gt;&lt;strong&gt;완속충전기:&lt;/strong&gt; 0.0 대&lt;br&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_a162268df8e7cd39503bdeadd0e733ae.setContent(html_7f8c2913104e5879510e95aa34958946);
#
#
#
#         marker_b7d6e2e6cd79d3ced8c63f64b0f843b3.bindPopup(popup_a162268df8e7cd39503bdeadd0e733ae)
#         ;
#
#
#
#
#             var marker_58816a58a77634679c61cc19f2a4fb5f = L.marker(
#                 [37.4831474, 127.0853694],
#                 {}
#             ).addTo(map_646bae944e3d31171b1b2704478c7e8e);
#
#
#         var popup_e71cee45f9cd9703be21107e32c26b9b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_1705cafbf14ae582fe0d76eda8674190 = $(`&lt;div id=&quot;html_1705cafbf14ae582fe0d76eda8674190&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;설치장소:&lt;/strong&gt; 가람아파트&lt;br&gt;&lt;strong&gt;주소:&lt;/strong&gt; 서울특별시 강남구 일원동 일원로 127&lt;br&gt;&lt;strong&gt;급속충전기:&lt;/strong&gt; 1.0 대&lt;br&gt;&lt;strong&gt;완속충전기:&lt;/strong&gt; 0.0 대&lt;br&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_e71cee45f9cd9703be21107e32c26b9b.setContent(html_1705cafbf14ae582fe0d76eda8674190);
#
#
#
#         marker_58816a58a77634679c61cc19f2a4fb5f.bindPopup(popup_e71cee45f9cd9703be21107e32c26b9b)
#         ;
#
#
#
#
#             var marker_a56132750a9e92023e1a12a5e6b578e8 = L.marker(
#                 [37.5147838, 127.0543618],
#                 {}
#             ).addTo(map_646bae944e3d31171b1b2704478c7e8e);
#
#
#         var popup_944fc980958b166399876c1477acf9c4 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_ccca6fcbb08ddef5cd4c2c62538e0465 = $(`&lt;div id=&quot;html_ccca6fcbb08ddef5cd4c2c62538e0465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;설치장소:&lt;/strong&gt; 강남구청 공영주차장&lt;br&gt;&lt;strong&gt;주소:&lt;/strong&gt; 서울특별시 강남구 삼성동 16-1&lt;br&gt;&lt;strong&gt;급속충전기:&lt;/strong&gt; 1.0 대&lt;br&gt;&lt;strong&gt;완속충전기:&lt;/strong&gt; 0.0 대&lt;br&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_944fc980958b166399876c1477acf9c4.setContent(html_ccca6fcbb08ddef5cd4c2c62538e0465);
#
#
#
#         marker_a561327

# %%
location_data = StationXY[['위도', '경도']].values[:len(StationXY)].tolist()

center = [37.541, 126.986]
m = folium.Map(location=center, zoom_start=10)

for i in range(len(StationXY)):
    if StationXY['급속충전기(대)'][i] > 0:
        station_color = 'royalblue'
    elif StationXY['완속충전기(대)'][i] > 0:
        station_color = 'indigo'

    popup_html = f"<strong>지원차종:</strong> {StationXY['지원차종'][i]}"

    folium.CircleMarker(
        location=location_data[i],
        radius=5,
        color=station_color,
        fill=True,
        popup=folium.Popup(html=popup_html, max_width=300),
    ).add_to(m)

plugins.MarkerCluster(location_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5032085292b19d9c7bf7f7d17d74c81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5032085292b19d9c7bf7f7d17d74c81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5032085292b19d9c7bf7f7d17d74c81 = L.map(
#                 &quot;map_e5032085292b19d9c7bf7f7d17d74c81&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c547af3e1e94e0752d377c786ba4fc92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c547af3e1e94e0752d377c786ba4fc92.addTo(map_e5032085292b19d9c7bf7f7d17d74c81);
#
#
#             var circle_marker_442f85484c14b02114b91f9881e39681 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;royalblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5032085292b19d9c7bf7f7d17d74c81);
#
#
#         var popup_bfea9bf9de9a1789c01f5d65b54c20fc = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_115eca241be331c194109b9ddd5379f1 = $(`&lt;div id=&quot;html_115eca241be331c194109b9ddd5379f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_bfea9bf9de9a1789c01f5d65b54c20fc.setContent(html_115eca241be331c194109b9ddd5379f1);
#
#
#
#         circle_marker_442f85484c14b02114b91f9881e39681.bindPopup(popup_bfea9bf9de9a1789c01f5d65b54c20fc)
#         ;
#
#
#
#
#             var circle_marker_f117e47fb61db4a94f507c83680a2913 = L.circleMarker(
#                 [0.0, 0.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;royalblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5032085292b19d9c7bf7f7d17d74c81);
#
#
#         var popup_686eaa520a3a00d70675a7944064dfcc = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_cb201af891ed68785f4f6bc87d61c422 = $(`&lt;div id=&quot;html_cb201af891ed68785f4f6bc87d61c422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];
#                 popup_686eaa520a3a00d70675a7944064dfcc.setContent(html_cb201af891ed68785f4f6bc87d61c422);
#
#
#
#         circle_marker_f117e47fb61db4a94f507c83680a2913.bindPopup(popup_686eaa520a3a00d70675a7944064dfcc)
#         ;
#
#
#
#
#             var circle_marker_fb56d80ea0b5951c91cfab32b6ca2c71 = L.circleMarker(
#                 [37.4831474, 127.0853694],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;royalblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;royalblue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5032085292b19d9c7bf7f7d17d74c81);
#
#
#         var popup_a2300e3bd3be976a8d50df189c876331 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_786ecccdf1d70d2e92c3559e254c38e8 = $(`&lt;div id=&quot;html_786ecccdf1d70d2e92c3559e254c38e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;지원차종:&lt;/strong&gt; SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라&lt;/div&gt;`)[0];

# %%
import pandas as pd
import pymysql


conn=pymysql.connect(host='database-1.cf8mgu8iylh3.ap-northeast-2.rds.amazonaws.com',port=3306,user='root',password='42314231',db='project')
sql="select * from 서울시_자치구별_충전방해_민원건수"

SeoulDisturb = pd.read_sql_query(sql,conn)
conn.close()
SeoulDisturb.head()
# Out:
# /tmp/ipykernel_4660/1292643368.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   SeoulDisturb = pd.read_sql_query(sql,conn)
#     구별 충전방해건수
# 0  강남구    599
# 1  강동구    988
# 2  강북구    479
# 3  강서구    340
# 4  관악구    348

# %%
SeoulDisturb = SeoulDisturb.rename(columns={'구별':'군구'})

# %%
SeoulData = pd.merge(SeoulData, SeoulDisturb)
SeoulData = SeoulData[['군구', '충전소갯수', '전기차수', '비율', '충전방해건수', '충전소갯수_비교', '전기차수_비교', 'X', 'Y']]
SeoulData.head()
# Out:
#     군구   충전소갯수     전기차수    비율 충전방해건수 충전소갯수_비교 전기차수_비교           X          Y
# 0  강남구  3613.0  14026.0  3.88    599       많음      많음  127.062985  37.496644
# 1  강동구  1709.0   2271.0  1.33    988       적음      적음  127.147012  37.550450
# 2  강북구   835.0    890.0  1.07    479       적음      적음  127.011189  37.643474
# 3  강서구  2604.0   2867.0  1.10    340       많음      많음  126.822807  37.561235
# 4  관악구   963.0   1355.0  1.41    348       적음      적음  126.945337  37.467376

# %%
SeoulData[['군구', '충전소갯수', '전기차수', '비율', '충전방해건수']]
# Out:
#       군구   충전소갯수     전기차수    비율 충전방해건수
# 0    강남구  3613.0  14026.0  3.88    599
# 1    강동구  1709.0   2271.0  1.33    988
# 2    강북구   835.0    890.0  1.07    479
# 3    강서구  2604.0   2867.0  1.10    340
# 4    관악구   963.0   1355.0  1.41    348
# 5    광진구   851.0   1069.0  1.26    307
# 6    구로구  2177.0   5161.0  2.37    513
# 7    금천구  1414.0   1033.0  0.73    529
# 8    노원구  2012.0   1561.0  0.78    213
# 9    도봉구  1049.0   1093.0  1.04    106
# 10  동대문구  1287.0   1112.0  0.86    482
# 11   동작구  1530.0   1203.0  0.79    597
# 12   마포구  2227.0   1776.0  0.80    259
# 13  서대문구  1238.0   1221.0  0.99    233
# 14   서초구  3055.0   4757.0  1.56    229
# 15   성동구  2462.0   2239.0  0.91    561
# 16   성북구  2291.0   1482.0  0.65    179
# 17   송파구  3183.0   3273.0  1.03    476
# 18   양천구  1363.0   1763.0  1.29    477
# 19  영등포구  2050.0   2182.0  1.06    193
# 20   용산구  1465.0   1201.0  0.82    324
# 21   은평구  1966.0   1533.0  0.78    448
# 22   종로구   934.0    907.0  0.97    988
# 23    중구  1331.0   2152.0  1.62    261
# 24   중랑구  1772.0   1457.0  0.82    332

# %%
SeoulData['충전방해건수'] = SeoulData['충전방해건수'].astype('float')
SeoulData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   군구        25 non-null     object
#  1   충전소갯수     25 non-null     float64
#  2   전기차수      25 non-null     float64
#  3   비율        25 non-null     float64
#  4   충전방해건수    25 non-null     float64
#  5   충전소갯수_비교  25 non-null     object
#  6   전기차수_비교   25 non-null     object
#  7   X         25 non-null     float64
#  8   Y         25 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 1.9+ KB

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(SeoulData)

fig, ax1 = plt.subplots()

df.plot(x='군구', y=['충전소갯수', '전기차수'], kind='bar', ax=ax1, rot=0, color=['#e35f62', 'mediumseagreen'], position=0.5, width=0.4)
df.plot(x='군구', y='충전방해건수', kind='line', ax=ax1, color='steelblue', marker='o')
ax1.set_ylabel('Count')
ax1.set_title('충전소갯수와 전기차수에 따른 충전방해건수')

ax1.set_xticklabels(df['군구'], rotation=45, ha='right', fontsize=8)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming SeoulData is a DataFrame with the required columns
df = pd.DataFrame(SeoulData)

# Create a figure and axis
fig, ax1 = plt.subplots()

# Plot bar plots for '충전소갯수' and '전기차수'
df.plot(x='군구', y=['충전소갯수', '전기차수'], kind='bar', ax=ax1, rot=45, color=['#e35f62', 'mediumseagreen'], width=0.8)

# Create a second y-axis to plot the line plot for '충전방해건수'
ax2 = ax1.twinx()
df.plot(x='군구', y='충전방해건수', kind='line', ax=ax2, color='steelblue', marker='o')

# Set labels and title
ax1.set_ylabel('Count (충전소갯수, 전기차수)')
ax2.set_ylabel('충전방해건수')
ax1.set_title('충전소갯수와 전기차수에 따른 충전방해건수')

# Set x-axis labels
ax1.set_xticklabels(df['군구'], rotation=45, ha='right', fontsize=8)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming SeoulData is a DataFrame with the required columns
df = pd.DataFrame(SeoulData)

# Pivot the data to create a matrix for '군구' vs. '전기차수' and '충전방해건수'
heatmap_data = df.pivot_table(index='군구', values=['전기차수', '충전방해건수'], aggfunc='mean')

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, cmap='Blues', fmt='.2f', linewidths=1)

# Set the title
plt.title('Heatmap of 전기차수 and 충전방해건수 by 군구')

# Show the plot
plt.show()

# %% [markdown]
# 2021년 기준 한국의 충전기 1대당 전기차 대수는 2.6대
#
# 2023년 말 기준 한국의 충전기 1대당 전기차 대수는 2.0대
#
# 정부는 2030년까지 전기차 1대당 충전기 3.4기를 확보한다는 목표
